# %% [markdown]
# # 04 - Análise descritiva dos resultados
#
# Carrega o CSV bruto gerado por `python -m src.pipeline.run_all` e produz:
# 1. Tabela-resumo com média e desvio das métricas por modelo.
# 2. Gráfico de barras da métrica principal (AUC OVO).
# 3. Boxplot da métrica por modelo.
# 4. Análise por regime (tamanho, número de classes, proporção categórica, missing).
# 5. Custo computacional vs. desempenho.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

import pandas as pd

from data.load_tabarena import summarize, RECOMMENDED_TASK_IDS
from src.reports.results_table import summary_by_model
from src.reports.plots import (
    bar_metric_by_model,
    boxplot_metric_by_model,
    bar_metric_by_regime,
    time_vs_quality,
)
from src.pipeline.regime import assign_regimes

# %%
raw = pd.read_csv('../results/raw.csv')
raw.head()
# Out:
#    task_id                           dataset        model   auc_ovo  accuracy  \
# 0    10101  blood-transfusion-service-center     lightgbm  0.769006  0.791111
# 1    10101  blood-transfusion-service-center      xgboost  0.717728  0.782222
# 2    10101  blood-transfusion-service-center     catboost  0.751841  0.791111
# 3    10101  blood-transfusion-service-center  group_model  0.766461  0.786667
# 4       37                          diabetes     lightgbm  0.839259  0.757576
#
#      g_mean  cross_entropy  fit_time_s  predict_time_s  total_time_s
# 0  0.597537       0.466000    0.475853        0.020821      0.496674
# 1  0.568371       0.509866    0.194277        0.014113      0.208390
# 2  0.571979       0.512734    0.816806        0.008261      0.825067
# 3  0.542737       0.462999   14.252822        0.068150     14.320972
# 4  0.688769       0.470954    0.079611        0.007182      0.086794

# %% [markdown]
# ## 1. Tabela-resumo por modelo

# %%
summary = summary_by_model(raw)
summary
# Out:
#          model  auc_ovo_mean  auc_ovo_std  accuracy_mean  accuracy_std  \
# 1  group_model      0.872953     0.092824       0.816369      0.118933
# 0     catboost      0.854164     0.083880       0.805136      0.111508
# 2     lightgbm      0.851064     0.080684       0.804060      0.109044
# 3      xgboost      0.835271     0.094099       0.797232      0.111599
#
#    g_mean_mean  g_mean_std  cross_entropy_mean  cross_entropy_std  \
# 1     0.694249    0.120675            0.399991           0.228896
# 0     0.581291    0.243688            0.509250           0.307596
# 2     0.580309    0.245499            0.451418           0.208413
# 3     0.580175    0.247486            0.509338           0.237281
#
#    total_time_s_mean  total_time_s_std
# 1         642.745020       1111.076594
# 0           2.566922          3.888231
# 2           0.889470          1.531896
# 3           1.114818          2.018521

# %% [markdown]
# ## 2. Gráfico de barras (AUC OVO)

# %%
fig = bar_metric_by_model(raw, metric='auc_ovo', output_path=Path('../results/figures/bar_auc.png'))
fig

# %% [markdown]
# ## 3. Boxplot por modelo

# %%
fig = boxplot_metric_by_model(raw, metric='auc_ovo', output_path=Path('../results/figures/box_auc.png'))
fig

# %% [markdown]
# ## 4. Análise por regime

# %%
metadata = assign_regimes(summarize(RECOMMENDED_TASK_IDS))
metadata
# Out:
#    task_id                              name  n_samples  n_features  \
# 0    10101  blood-transfusion-service-center        748           4
# 1       37                          diabetes        768           8
# 2       11                     balance-scale        625           4
# 3       31                          credit-g       1000          20
# 4     9952                           phoneme       5404           5
# 5       23                               cmc       1473           9
# 6     7592                             adult      48842          14
# 7    14965                    bank-marketing      45211          16
# 8   146195                         connect-4      67557          42
#
#    n_classes  n_categorical  has_missing  regime regime_size regime_classes  \
# 0          2              0        False   small       small         binary
# 1          2              0        False   small       small         binary
# 2          3              0        False   small       small     multiclass
# 3          2             13        False  medium      medium         binary
# 4          2              0        False  medium      medium         binary
# 5          3              7        False  medium      medium     multiclass
# 6          2              8         True   large       large         binary
# 7          2              9        False   large       large         binary
# 8          3             42        False   large       large     multiclass
#
#   regime_cat_share regime_missing
# 0              low             no
# 1              low             no
# 2              low             no
# 3             high             no
# 4              low             no
# 5             high             no
# 6             high            yes
# 7             high             no
# 8             high             no

# %%
for col in ['regime_size', 'regime_classes', 'regime_cat_share', 'regime_missing']:
    fig = bar_metric_by_regime(
        raw, metadata, regime_col=col, metric='auc_ovo',
        output_path=Path(f'../results/figures/regime_{col}.png'),
    )
    fig.suptitle('')
    fig.show()
# Out:
# C:\Users\rafap\AppData\Local\Temp\ipykernel_30636\3580374308.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\rafap\AppData\Local\Temp\ipykernel_30636\3580374308.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\rafap\AppData\Local\Temp\ipykernel_30636\3580374308.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\rafap\AppData\Local\Temp\ipykernel_30636\3580374308.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## 5. Custo computacional vs. desempenho

# %%
print(raw.groupby('model')['total_time_s'].agg(['mean','sum']).round(1).to_string())
# Out:
#               mean     sum
# model
# catboost       2.6    23.1
# group_model  642.7  5784.7
# lightgbm       0.9     8.0
# xgboost        1.1    10.0

# %%
fig = time_vs_quality(raw, x='total_time_s', y='auc_ovo', output_path=Path('../results/figures/time_vs_quality.png'))
fig

# %% [markdown]
# ## 6. Ranking do TabM por dataset

# %%
pivot = raw.pivot_table(index=['task_id','dataset'], columns='model', values='auc_ovo').reset_index()
cols = ['group_model','catboost','lightgbm','xgboost']
pivot['tabm_rank'] = pivot[cols].rank(axis=1, ascending=False)['group_model'].astype(int)
pivot[['dataset','group_model','lightgbm','catboost','xgboost','tabm_rank']].sort_values('tabm_rank').round(4)
# Out:
# model                           dataset  group_model  lightgbm  catboost  \
# 0                         balance-scale       0.9955    0.8362    0.8857
# 1                                   cmc       0.7556    0.7441    0.7469
# 3                              diabetes       0.8542    0.8393    0.8142
# 5                               phoneme       0.9468    0.9376    0.9463
# 7                        bank-marketing       0.9354    0.9321    0.9336
# 8                             connect-4       0.9324    0.9185    0.9144
# 6      blood-transfusion-service-center       0.7665    0.7690    0.7518
# 2                              credit-g       0.7554    0.7555    0.7660
# 4                                 adult       0.9148    0.9274    0.9285
#
# model  xgboost  tabm_rank
# 0       0.7836          1
# 1       0.7365          1
# 3       0.8314          1
# 5       0.9455          1
# 7       0.9291          1
# 8       0.9106          1
# 6       0.7177          2
# 2       0.7368          3
# 4       0.9261          4

# %% [markdown]
# ## 7. Bootstrap IC 95% — TabM

# %%
rng = np.random.default_rng(42)
def bootstrap_ci(arr, n=1000):
    means = [np.mean(rng.choice(arr, len(arr), replace=True)) for _ in range(n)]
    return np.percentile(means, [2.5, 97.5])

tabm = raw[raw.model=='group_model']
rows = []
for m in ['auc_ovo','accuracy','g_mean','cross_entropy','total_time_s']:
    v = tabm[m].values
    lo, hi = bootstrap_ci(v)
    rows.append({'Métrica':m,'Média':f'{v.mean():.4f}','DP':f'{v.std():.4f}','IC 95%':f'[{lo:.4f}; {hi:.4f}]'})
pd.DataFrame(rows)
# Out:
#          Métrica     Média         DP                 IC 95%
# 0        auc_ovo    0.8730     0.0875       [0.8165; 0.9325]
# 1       accuracy    0.8164     0.1121       [0.7399; 0.8823]
# 2         g_mean    0.6942     0.1138       [0.6220; 0.7708]
# 3  cross_entropy    0.4000     0.2158       [0.2697; 0.5601]
# 4   total_time_s  642.7450  1047.5331  [124.5303; 1399.8838]
